# %%
# === Create HAM10000_modified with 1 image per lesion ===

import pandas as pd
import numpy as np
from pathlib import Path
import shutil
from tqdm import tqdm

# Adjust if notebook is not inside EDA/
PROJECT_ROOT = Path("..")
SRC_DATA = PROJECT_ROOT / "Data" / "HAM10000_data"

META_PATH = SRC_DATA / "HAM10000_metadata.csv"
IMG1 = SRC_DATA / "HAM10000_images_part_1"
IMG2 = SRC_DATA / "HAM10000_images_part_2"

# Output
OUT_DATA = PROJECT_ROOT / "Data" / "HAM10000_modified"
OUT_IMAGES = OUT_DATA / "images"
OUT_META = OUT_DATA / "HAM10000_metadata_modified.csv"
OUT_MAP = OUT_DATA / "lesion_to_image_mapping.csv"

OUT_IMAGES.mkdir(parents=True, exist_ok=True)

print("Reading:", META_PATH)
print("Writing images to:", OUT_IMAGES)
# Out:
# Reading: ../Data/HAM10000_data/HAM10000_metadata.csv
# Writing images to: ../Data/HAM10000_modified/images

# %%
df = pd.read_csv(META_PATH)

# For reproducibility
SEED = 42

# Choose ONE image per lesion_id uniformly at random
df_one = (
    df.groupby("lesion_id", group_keys=False)
      .apply(lambda g: g.sample(n=1, random_state=SEED))
      .reset_index(drop=True)
)

print("Original rows (images):", len(df))
print("Unique lesions:", df["lesion_id"].nunique())
print("New rows (1 per lesion):", len(df_one))

df_one.head()
# Out:
# Original rows (images): 10015
# Unique lesions: 7470
# New rows (1 per lesion): 7470
# /var/folders/tc/p_2dw00d5zg0svx3_qj__8tc0000gn/T/ipykernel_31298/2823211978.py:9: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   .apply(lambda g: g.sample(n=1, random_state=SEED))
#      lesion_id      image_id   dx    dx_type   age     sex     localization
# 0  HAM_0000000  ISIC_0025346   nv      histo  60.0    male             back
# 1  HAM_0000001  ISIC_0027859  bkl      histo  70.0  female             face
# 2  HAM_0000002  ISIC_0033848  mel      histo  65.0  female  lower extremity
# 3  HAM_0000003  ISIC_0027886   nv  follow_up  55.0    male            trunk
# 4  HAM_0000004  ISIC_0024645   nv  follow_up  40.0  female             back

# %%
def find_image_path(image_id: str) -> Path:
    p1 = IMG1 / f"{image_id}.jpg"
    if p1.exists():
        return p1
    p2 = IMG2 / f"{image_id}.jpg"
    if p2.exists():
        return p2
    return None

missing = []
for img_id in tqdm(df_one["image_id"].tolist(), desc="Copying images"):
    src = find_image_path(img_id)
    if src is None:
        missing.append(img_id)
        continue
    dst = OUT_IMAGES / f"{img_id}.jpg"
    if not dst.exists():  # don't recopy if rerun
        shutil.copy2(src, dst)

print(f"Done. Missing images: {len(missing)}")
if missing:
    print("First missing ids:", missing[:10])
# Out:
# Copying images:  10%|▉         | 731/7470 [12:59<1:59:46,  1.07s/it]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[3], line 18
#      16     dst = OUT_IMAGES / f"{img_id}.jpg"
#      17     if not dst.exists():  # don't recopy if rerun
# ---> 18         shutil.copy2(src, dst)
#      20 print(f"Done. Missing images: {len(missing)}")
#      21 if missing:
#
# File ~/anaconda3/envs/MLDM/lib/python3.11/shutil.py:436, in copy2(src, dst, follow_symlinks)
#     434 if os.path.isdir(dst):
#     435     dst = os.path.join(dst, os.path.basename(src))
# --> 436 copyfile(src, dst, follow_symlinks=follow_symlinks)
#     437 copystat(src, dst, follow_symlinks=follow_symlinks)
#     438 return dst
#
# File ~/anaconda3/envs/MLDM/lib/python3.11/shutil.py:262, in copyfile(src, dst, follow_symlinks)
#     260 if _HAS_FCOPYFILE:
#     261     try:
# --> 262         _fastcopy_fcopyfile(fsrc, fdst, posix._COPYFILE_DATA)
#     263         return dst
#     264     except _GiveupOnFastCopy:
#
# File ~/anaconda3/envs/MLDM/lib/python3.11/shutil.py:97, in _fastcopy_fcopyfile(fsrc, fdst, flags)
#      94     raise _GiveupOnFastCopy(err)  # not a regular file
#      96 try:
# ---> 97     posix._fcopyfile(infd, outfd, flags)
#      98 except OSError as err:
#      99     err.filename = fsrc.name
#
# KeyboardInterrupt:

# %%
# Save modified metadata (only selected images)
df_one.to_csv(OUT_META, index=False)

# Save mapping lesion_id -> chosen image_id (nice for tracking)
df_one[["lesion_id", "image_id", "dx"]].to_csv(OUT_MAP, index=False)

print("Saved:", OUT_META)
print("Saved:", OUT_MAP)
print("Images in output folder:", len(list(OUT_IMAGES.glob("*.jpg"))))

# %%
# 1) Exactly one image per lesion
assert df_one["lesion_id"].nunique() == len(df_one), "Not exactly 1 row per lesion!"

# 2) All output images exist
missing_files = [img for img in df_one["image_id"] if not (OUT_IMAGES / f"{img}.jpg").exists()]
print("Missing copied files:", len(missing_files))

# 3) Compare class distributions (image-level vs lesion-level single-image)
print("\nClass counts (original):")
print(df["dx"].value_counts())

print("\nClass counts (one per lesion):")
print(df_one["dx"].value_counts())
